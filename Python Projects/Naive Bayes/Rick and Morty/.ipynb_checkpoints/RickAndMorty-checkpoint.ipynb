# %%
import pandas as pd
import string as srt
import re

# %%
df = pd.read_csv("RickAndMorty.csv")
df
# Out:
#       index  season no.  episode no.            episode name   name  \
# 0         0           1            1                   Pilot   Rick
# 1         1           1            1                   Pilot  Morty
# 2         2           1            1                   Pilot   Rick
# 3         3           1            1                   Pilot  Morty
# 4         4           1            1                   Pilot   Rick
# ...     ...         ...          ...                     ...    ...
# 1900   2483           3            7  Tales From the Citadel  Morty
# 1901   2484           3            7  Tales From the Citadel   Rick
# 1902   2485           3            7  Tales From the Citadel  Morty
# 1903   2486           3            7  Tales From the Citadel   Rick
# 1904   2487           3            7  Tales From the Citadel  Morty
#
#                                                    line
# 0     Morty! You gotta come on. Jus'... you gotta co...
# ...

# %%
for i in range(0, len(df.index)):
    message = df.iat[i,5]
    print(message)
    if(message.isalpha() == False):
        testLine = re.sub('[!@#$?]', '', message)
        message = message.upper()
df.dropna(axis = 0, inplace = True )
df.drop(["episode name"], axis = 1, inplace = True)
df.drop(["episode no."], axis = 1, inplace = True)
df.head()
# Out:
# Morty! You gotta come on. Jus'... you gotta come with me.
# What, Rick? What’s going on?
# I got a surprise for you, Morty.
# It's the middle of the night. What are you talking about?
# Come on, I got a surprise for you.  Come on, hurry up.
# Ow! Ow! You're tugging me too hard!
# We gotta go, gotta get outta here, come on. Got a surprise for you Morty.
# What do you think of this... flying vehicle, Morty? I built it outta stuff I found in the garage.
# Yeah, Rick... I-it's great. Is this the surprise?
# Morty. I had to... I had to do it. I had— I had to— I had to make a bomb, Morty. I had to create a bomb.
# What?! A bomb?!
# We're gonna drop it down there just get a whole fresh start, Morty. Create a whole fresh start.
# T-t-that's absolutely crazy!
# Come on, Morty. Just take it easy, Morty. It's gonna be good. Right now, we're gonna go pick up your little friend Jessica.
# Jessica? From my math class?
# ...

# %%
for i in range(0, len(df.index)):
    count = 0 # TAKE COUNT OF how often the message appears in the list 
    checkList = [] # standard list.
    checkList.append(message) #message is going to get placed into checklist 
    if (checkList[i] == checkList[i]): #if message contains itself we append that to count 
        count = count + 1 
        print(checkList[i], "=", count)
    else:
        print("An error has occured.")
            
    print(checkList)
# Out:
# WHOO! YEAH! YEAAH! OHHH, SHIT! = 1
# ['WHOO! YEAH! YEAAH! OHHH, SHIT!']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 5
#       3 checkList = [] # standard list.
#       4 checkList.append(message) #message is going to get placed into checklist
# ----> 5 if (checkList[i] == checkList[i]): #if message contains itself we append that to count
#       6     count = count + 1
#       7     print(checkList[i], "=", count)
#
# IndexError: list index out of range

# %%
stopWords = []
if(stopWords.contains()
