# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#       rental_id     rent  bedrooms  bathrooms  size_sqft  min_to_subway  \
# 0          1545   2550.0       0.0          1      480.0              9
# 1          2472  11500.0       2.0          2     2000.0              4
# 2          2919   4500.0       1.0          1      916.0              2
# 3          2790   4795.0       1.0          1      975.0              3
# 4          3946  17500.0       2.0          2     4800.0              3
# ...         ...      ...       ...        ...        ...            ...
# 3534       7582   4210.0       1.0          1      532.0              3
# 3535       5686   6675.0       2.0          2      988.0              5
# 3536       9679   1699.0       0.0          1      250.0              2
# 3537       5188   3475.0       1.0          1      651.0              6
# 3538       4718   4500.0       1.0          1      816.0              4
#
#       floor  building_age_yrs
# 0       2.0                17
# 1       1.0                96
# 2      51.0                29
# 3       8.0                31
# 4       4.0               136
# ...     ...               ...
# 3534    8.0                16
# 3535   10.0                 9
# 3536    5.0                96
# 3537    5.0                14
# 3538   11.0                 9
#
# [3539 rows x 8 columns]

# %%
df.dropna(inplace="true" )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9512\2023120696.py in <module>
# ----> 1 df.dropna(inplace="true" )
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5992         1  Batman  Batmobile 1940-04-25
#    5993         """
# -> 5994         inplace = validate_bool_kwarg(inplace, "inplace")
#    5995         if isinstance(axis, (tuple, list)):
#    5996             # GH20987
#
# ~\Anaconda3\lib\site-packages\pandas\util\_validators.py in validate_bool_kwarg(value, arg_name, none_allowed, int_allowed)
#     249
#     250     if not good_value:
# --> 251         raise ValueError(
#     252             f'For argument "{arg_name}" expected type bool, received '
#     253             f"type {type(value).__name__}."
#
# ValueError: For argument "inplace" expected type bool, received type str.

# %%
df.dropna(axis = 1 ,how="any") #drop rows
# Out:
#       rental_id  bedrooms  bathrooms  min_to_subway  building_age_yrs
# 0          1545       0.0          1              9                17
# 1          2472       2.0          2              4                96
# 2          2919       1.0          1              2                29
# 3          2790       1.0          1              3                31
# 4          3946       2.0          2              3               136
# ...         ...       ...        ...            ...               ...
# 3534       7582       1.0          1              3                16
# 3535       5686       2.0          2              5                 9
# 3536       9679       0.0          1              2                96
# 3537       5188       1.0          1              6                14
# 3538       4718       1.0          1              4                 9
#
# [3539 rows x 5 columns]

# %%
df.plot.scatter(x = "size_sqft", y = "rent")
# Out:
# <AxesSubplot:xlabel='size_sqft', ylabel='rent'>

# %%
def linearPlane(x,y,z,a,b,c,zxis,xaxis):
    z = 1 # z is a constant 
    ax + bx +cx + zx = 0  #implement a strategy that subtracts zx
    zx - 1 #in real life zx is going to be positive so we will have to apply onthat
    a = [x1,x2, xconst][y1,y2, yconst] #copy this over so we will be able to times 
    transpose = (x1,x2, xconst) * (y1,y2, yconst) #transpose function 
    filledafunc = zxis * transpose # time to do transpose multiplication
    filledxfunc = transpose * transpose
    
    GraphFromPlane = a + b + c + d / **((sqrt)a + (sqrt)b + (sqrt)c  )
    
linearPlane()
# Out:
#   File "C:\Users\achen12\AppData\Local\Temp\ipykernel_9512\1563198295.py", line 3
#     ax + bx +cx + zx = 0  #implement a strategy that subtracts zx
#     ^
# SyntaxError: cannot assign to operator

# %%
for i in range(0, len(df.index)):
    df.iloc[0]
