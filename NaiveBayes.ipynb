# %%
import pandas as pd 
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_svmlight_file

# %%
df = pd.read_csv('stopwords.txt', sep=' ', header=None)# names=[“Column1”, “Column2”
df2 = pd.read_csv("Spam.csv")
gnb = GaussianNB()
#gnb.fit(x, y) #compare stopwords and spam 
countMessage = []
df
df2
# Out:
#      Label                                            Message Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will �_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
def convert():
    df.upper()

# %%
def alphabet():
    alphabet = {"A" : 1, "B" : 2, "C" : 3, "D" : 4, "F" = 5 }

# %%
def contains(): # drop words that does not contain stop words
    for i in range(0, len(df.index)):
        testMessage = df2.iat[i, 1]
        i = i + 1
        if testMessage not in df: #df contains stopwords.txt
            df.dropna(axis=0, inplace= True)  
            print(df)
        else:
            return 0
        
            
contains()
# Out:
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]

# %%
def thsh():
    for i in range(0, len(df.index)): #to get the words we need to add up 
        cleanMessage = df2.iat[i, 1]
        i = i + 1 
        df.append(cleanMessage(countMessage))
thsh()
    # to find the top 5 words count the number of numbers but it will be in string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17096\1239841478.py in <module>
#       4         i = i + 1
#       5         df.append(cleanMessage(countMessage))
# ----> 6 thsh()
#       7     # to find the top 5 words count the number of numbers but it will be in string
#
# ~\AppData\Local\Temp\ipykernel_17096\1239841478.py in thsh()
#       3         cleanMessage = df2.iat[i, 1]
#       4         i = i + 1
# ----> 5         df.append(cleanMessage(countMessage))
#       6 thsh()
#       7     # to find the top 5 words count the number of numbers but it will be in string
#
# TypeError: 'str' object is not callable
