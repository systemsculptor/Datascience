# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#       total_experience_years  annual_base_pay
# 0                       13.0         125000.0
# 1                       15.0          65000.0
# 2                        4.0          86000.0
# 3                        4.0         105000.0
# 4                        4.0         110000.0
# ...                      ...              ...
# 1650                     1.0          60500.0
# 1651                     6.0         164000.0
# 1652                     7.0         150000.0
# 1653                     5.0          75000.0
# 1654                     2.0             50.0
#
# [1655 rows x 2 columns]

# %%
def appendList():
    for i in range(0, len(df.index)):
            values = df.loc[i]
            print(values)
    print(type(values))
appendList()
# Out:
# total_experience_years        13.0
# annual_base_pay           125000.0
# Name: 0, dtype: float64
# total_experience_years       15.0
# annual_base_pay           65000.0
# Name: 1, dtype: float64
# total_experience_years        4.0
# annual_base_pay           86000.0
# Name: 2, dtype: float64
# total_experience_years         4.0
# annual_base_pay           105000.0
# Name: 3, dtype: float64
# total_experience_years         4.0
# annual_base_pay           110000.0
# Name: 4, dtype: float64
# total_experience_years        5.0
# annual_base_pay           40000.0
# Name: 5, dtype: float64
# total_experience_years        4.0
# annual_base_pay           45000.0
# Name: 6, dtype: float64
# total_experience_years         8.0
# annual_base_pay           135000.0
# Name: 7, dtype: float64
# total_experience_years         2.0
# annual_base_pay           105000.0
# Name: 8, dtype: float64
# total_experience_years        1.0
# annual_base_pay           80000.0
# Name: 9, dtype: float64
# ...

# %%
scatter = df.plot.scatter( x="total_experience_years", y="annual_base_pay")
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag

# %%
def data(x1,x2,y1,y2):
    d = (sqrt(x1 - x2)) + (sqrt(y1 + y2))
    sum = 0
