# %%
import pandas as pd 
import string as s
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_svmlight_file

# %%
df = pd.read_csv('stopwords.txt', sep=' ', header=None )# names=[“Column1”, “Column2”
df2 = pd.read_csv("Spam.csv")
gnb = GaussianNB()
#gnb.fit(x, y) #compare stopwords and spam 
df
# Out:
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]

# %%
df2
# Out:
#      Label                                            Message Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will �_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
def convert():
    str.upper(df) 
    str.upper(df2)
convert()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17096\2566930870.py in <module>
#       3     str.upper(df2)
#       4
# ----> 5 convert()
#
# ~\AppData\Local\Temp\ipykernel_17096\2566930870.py in convert()
#       1 def convert():
# ----> 2     str.upper(df)
#       3     str.upper(df2)
#       4
#       5 convert()
#
# TypeError: descriptor 'upper' for 'str' objects doesn't apply to a 'DataFrame' object

# %%
for x in testMessage:
    newList.append(x.upper())
for j in df:
    testList.append(x.upper())
# Out:
# [          0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]]

# %%
def alphabet():
    alphabet = {"A" : 1, "B" : 2, "C" : 3, "D" : 4, "F" = 5 }
# Out:
#   File "C:\Users\achen12\AppData\Local\Temp\ipykernel_17096\2180036473.py", line 2
#     alphabet = {"A" : 1, "B" : 2, "C" : 3, "D" : 4, "F" = 5 }
#                                                         ^
# SyntaxError: invalid syntax

# %%
 # drop words that does not contain stop words
for i in range(0, len(df.index)):
    testMessage = df2.iat[i, 1]
    testMessage = str.upper(testMessage)
    print(testMessage)
    i = i + 1 
    if testMessage not in df: #df contains stopwords.txt
        df.dropna(axis=0, inplace = True)  
        print(df)
    else:
        print("NOT IN")
# Out:
# GO UNTIL JURONG POINT, CRAZY.. AVAILABLE ONLY IN BUGIS N GREAT WORLD LA E BUFFET... CINE THERE GOT AMORE WAT...
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
# OK LAR... JOKING WIF U ONI...
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
# FREE ENTRY IN 2 A WKLY COMP TO WIN FA CUP FINAL TKTS 21ST MAY 2005. TEXT FA TO 87121 TO RECEIVE ENTRY QUESTION(STD TXT RATE)T&C'S APPLY 08452810075OVER18'S
#           0
# 0         i
# 1        me
# 2        my
# 3    myself
# 4        we
# ..      ...
# 122    will
# 123    just
# 124     don
# 125  should
# 126     now
#
# [127 rows x 1 columns]
# U DUN SAY SO EARLY HOR... U C ALREADY THEN SAY...
#           0
# 0         i
# 1        me
# 2        my
# ...

# %%
for i in range(0, len(df.index)):#to get the words we need to add up 
    countMessage = []
    if testMessage in df:
        countMessage.append(testMessage)
        i = i + 1 
    else:
        print("null")
    print(countMessage) 
thsh()
# Out:
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# null
# []
# ...

# %%
print(countMessage)
# Out:
# []

# %%
def vectorize(df, top):
    for
# Out:
#   File "C:\Users\achen12\AppData\Local\Temp\ipykernel_17096\2457849405.py", line 1
#     def vectorize(df, top):
#                            ^
# IndentationError: expected an indented block

# %%
def naiveBayes()
