# %%
import pandas as pd
import string as srt
import re

# %%
df = pd.read_csv("RickAndMorty.csv")
df
# Out:
#       index  season no.  episode no.            episode name   name  \
# 0         0           1            1                   Pilot   Rick
# 1         1           1            1                   Pilot  Morty
# 2         2           1            1                   Pilot   Rick
# 3         3           1            1                   Pilot  Morty
# 4         4           1            1                   Pilot   Rick
# ...     ...         ...          ...                     ...    ...
# 1900   2483           3            7  Tales From the Citadel  Morty
# 1901   2484           3            7  Tales From the Citadel   Rick
# 1902   2485           3            7  Tales From the Citadel  Morty
# 1903   2486           3            7  Tales From the Citadel   Rick
# 1904   2487           3            7  Tales From the Citadel  Morty
#
#                                                    line
# 0     Morty! You gotta come on. Jus'... you gotta co...
# ...

# %%
for i in range(0, len(df.index)):
    message = df.iat[i,5]
    print(message)
    if(message.isalpha() == False):
        testLine = re.sub('[!@#$]', ' ', message)
        message = message.upper()
df.dropna(axis = 0, inplace = True )
df.drop(["episode name"], axis = 1, inplace = True)
df.drop(["episode no."], axis = 1, inplace = True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19524\3763346189.py in <module>
#       1 for i in range(0, len(df.index)):
# ----> 2     message = df.iat[i,5]
#       3     print(message)
#       4     if(message.isalpha() == False):
#       5         testLine = re.sub('[!@#$]', ' ', message)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2224
#    2225         key = self._convert_key(key)
# -> 2226         return self.obj._get_value(*key, takeable=self._takeable)
#    2227
#    2228     def __setitem__(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    3610         """
#    3611         if takeable:
# -> 3612             series = self._ixs(col, axis=1)
#    3613             return series._values[index]
# ...

# %%
# Out:
#       index  season no.   name  \
# 0         0           1   Rick
# 1         1           1  Morty
# 2         2           1   Rick
# 3         3           1  Morty
# 4         4           1   Rick
# ...     ...         ...    ...
# 1900   2483           3  Morty
# 1901   2484           3   Rick
# 1902   2485           3  Morty
# 1903   2486           3   Rick
# 1904   2487           3  Morty
#
#                                                    line
# 0     Morty! You gotta come on. Jus'... you gotta co...
# 1                          What, Rick? What’s going on?
# 2                      I got a surprise for you, Morty.
# 3     It's the middle of the night. What are you tal...
# 4     Come on, I got a surprise for you.  Come on, h...
# ...                                                 ...
# 1900                                  That was amazing!
# 1901                     Got some of that mermaid puss!
# 1902  I'm really hoping it wasn't a one-off thing an...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19524\446589371.py in <module>
#       1 for i in range(0, len(df.index)):
# ----> 2     message = df.iat[i,4]
#       3     upperCase = srt.upper(str(message))
#       4     print(message)
#       5     i = i + 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2224
#    2225         key = self._convert_key(key)
# -> 2226         return self.obj._get_value(*key, takeable=self._takeable)
#    2227
#    2228     def __setitem__(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    3610         """
#    3611         if takeable:
# -> 3612             series = self._ixs(col, axis=1)
#    3613             return series._values[index]
#    3614
#
# ...

# %% [raw]
# def stopWords():

# %%
def RickCount()
    rickList = []

# %%
def mrsPancake()
if (df.columns["Mrs.pancake"]  )
    message.append(pancakeList) )
    pancakeList = []

# %%
def MrGoldenfold()
    if()
    goldenList = []

# %%
def MortyCount():
    mortyList = []
    if()
    message.append(mortyList)
# Out:
#   File "C:\Users\achen12\AppData\Local\Temp\ipykernel_19524\1540582109.py", line 1
#     def MortyCount():
#                      ^
# IndentationError: expected an indented block

# %%
def stopWords():
    if (message.contains(stopwords)):
        if message == "Morty" || message == " "
# Out:
#   File "C:\Users\achen12\AppData\Local\Temp\ipykernel_19524\139494753.py", line 2
#     if message.contains(stopwords):
#                                    ^
# IndentationError: expected an indented block
